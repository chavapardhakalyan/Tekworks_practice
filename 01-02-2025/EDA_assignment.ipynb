# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("data job posts.csv")

# %%
data.head()
# Out:
#                                              jobpost          date  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1  International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2  Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3  Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4  Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode Term  \
# 0             AMERIA Investment Consulting Company              NaN  NaN
# 1  International Research & Exchanges Board (IREX)              NaN  NaN
# ...

# %%
#Check for missing values in all columns
data.isna().sum()
# Out:
# jobpost                 0
# date                    0
# Title                  28
# Company                 7
# AnnouncementCode    17793
# Term                11325
# Eligibility         14071
# Audience            18361
# StartDate            9326
# Duration             8203
# Location               32
# JobDescription       3892
# JobRequirment        2522
# RequiredQual          484
# Salary               9379
# ApplicationP           60
# OpeningDate           706
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
#Handling null values of 'Title' column
data['Title'] = data['Title'].fillna("Unknown")

# %%
#Handling null values of 'Company' column
data['Company'] = data['Company'].fillna("Unknown")

# %%
#Handling null values of 'AnnouncementCode' column
data['AnnouncementCode'] = data['AnnouncementCode'].fillna("Unknown")

# %%
#Handling null values of 'Term' column
data['Term'] = data['Term'].fillna("Unknown")

# %%
#Handling null values of 'Eligibility' column
data['Eligibility'] = data['Eligibility'].fillna("Unknown")

# %%
data.isna().sum()
# Out:
# jobpost                 0
# date                    0
# Title                   0
# Company                 0
# AnnouncementCode        0
# Term                    0
# Eligibility             0
# Audience            18361
# StartDate            9326
# Duration             8203
# Location               32
# JobDescription       3892
# JobRequirment        2522
# RequiredQual          484
# Salary               9379
# ApplicationP           60
# OpeningDate           706
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
#Handling null values of "Audience" column
audience_data = data['Audience'].unique()
duplicate = data['Audience'].value_counts()
duplicate
data['Audience'] = data['Audience'].fillna("Unknown")

# %%
data.isna().sum()
# Out:
# jobpost                 0
# date                    0
# Title                   0
# Company                 0
# AnnouncementCode        0
# Term                    0
# Eligibility             0
# Audience                0
# StartDate            9326
# Duration             8203
# Location               32
# JobDescription       3892
# JobRequirment        2522
# RequiredQual          484
# Salary               9379
# ApplicationP           60
# OpeningDate           706
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
#handling null values of 'StartDate' column
data['StartDate'].unique()
data['StartDate'] = data['StartDate'].fillna("Unknown")

# %%
#Handling null values of 'Duration' column
duration_data = data['Duration'].unique()
duplicates = data['Duration'].value_counts()
data['Duration'] = data['Duration'].fillna("Unknown")

# %%
#Handling null values of 'Location' column
data['Location'].unique()
duplicates = data['Location'].value_counts()
data['Location'].fillna(data['Location'].mode()[0])
# Out:
# 0                                         Yerevan, Armenia
# 1        IREX Armenia Main Office; Yerevan, Armenia \r\...
# 2                                         Yerevan, Armenia
# 3                                      Manila, Philippines
# 4                                         Yerevan, Armenia
#                                ...
# 18996                                     Yerevan, Armenia
# 18997                                     Yerevan, Armenia
# 18998                                     Yerevan, Armenia
# 18999                                     Yerevan, Armenia
# 19000                                     Yerevan, Armenia
# Name: Location, Length: 19001, dtype: object

# %%
#Handling null values of 'JobDescription' column

# %%
data['JobDescription'].unique()
# Out:
# array(["AMERIA Investment Consulting Company is seeking a\r\nChief Financial Officer. This position manages the company's fiscal and\r\nadministrative functions, provides highly responsible and technically\r\ncomplex staff assistance to the Executive Director. The work performed\r\nrequires a high level of technical proficiency in financial management\r\nand investment management, as well as management, supervisory, and\r\nadministrative skills.",
#        nan,
#        'Public outreach and strengthening of a growing\r\nnetwork of environmental NGOs, businesses, international organizations\r\nand public agencies. Will serve as primary contact between CENN and\r\npublic. This is a full-time position.',
#        ...,
# ...

# %%
#Handling null values of 'JobDescription' column
data['JobDescription'] = data['JobDescription'].fillna(data['JobDescription'].mode()[0])

# %%
data.isna().sum()
# Out:
# jobpost                 0
# date                    0
# Title                   0
# Company                 0
# AnnouncementCode        0
# Term                    0
# Eligibility             0
# Audience                0
# StartDate               0
# Duration                0
# Location               32
# JobDescription          0
# JobRequirment        2522
# RequiredQual          484
# Salary               9379
# ApplicationP           60
# OpeningDate           706
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
#Handling null values of 'JobRequirment'column
data['JobRequirment'].value_counts()
data['JobRequirment'] = data['JobRequirment'].fillna(data['JobRequirment'].mode()[0])

# %%
data.isna().sum()
# Out:
# jobpost                 0
# date                    0
# Title                   0
# Company                 0
# AnnouncementCode        0
# Term                    0
# Eligibility             0
# Audience                0
# StartDate               0
# Duration                0
# Location               32
# JobDescription          0
# JobRequirment           0
# RequiredQual          484
# Salary               9379
# ApplicationP           60
# OpeningDate           706
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
data.isna().sum()
# Out:
# jobpost                 0
# date                    0
# Title                   0
# Company                 0
# AnnouncementCode        0
# Term                    0
# Eligibility             0
# Audience                0
# StartDate               0
# Duration                0
# Location               32
# JobDescription          0
# JobRequirment           0
# RequiredQual          484
# Salary               9379
# ApplicationP           60
# OpeningDate           706
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
#Handling null values of 'RequiredQual' column
data['RequiredQual'].value_counts()
data['RequiredQual'] = data['RequiredQual'].fillna(data['RequiredQual'].mode()[0])

# %%
data.isna().sum()
# Out:
# jobpost                 0
# date                    0
# Title                   0
# Company                 0
# AnnouncementCode        0
# Term                    0
# Eligibility             0
# Audience                0
# StartDate               0
# Duration                0
# Location               32
# JobDescription          0
# JobRequirment           0
# RequiredQual            0
# Salary               9379
# ApplicationP           60
# OpeningDate           706
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
data['Salary'].value_counts()
data['Salary'] = data['Salary'].fillna(data['Salary'].mode()[0])

# %%
data.isna().sum()
# Out:
# jobpost                 0
# date                    0
# Title                   0
# Company                 0
# AnnouncementCode        0
# Term                    0
# Eligibility             0
# Audience                0
# StartDate               0
# Duration                0
# Location               32
# JobDescription          0
# JobRequirment           0
# RequiredQual            0
# Salary                  0
# ApplicationP           60
# OpeningDate           706
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
data['Salary'] = data['Salary'].astype(str)
data['Salary'] = data['Salary'].fillna(data['Salary'].mode()[0])

# %%
data.isna().sum()
# Out:
# jobpost                 0
# date                    0
# Title                   0
# Company                 0
# AnnouncementCode        0
# Term                    0
# Eligibility             0
# Audience                0
# StartDate               0
# Duration                0
# Location               32
# JobDescription          0
# JobRequirment           0
# RequiredQual            0
# Salary                  0
# ApplicationP           60
# OpeningDate           706
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
#Handling null values of 'Location' column
data['Location'].unique()
duplicates = data['Location'].value_counts()
data['Location'].fillna(data['Location'].mode()[0],inplace=True)
# Out:
# /var/folders/cr/nsmtzvws1dd3gq7d3vnrz2c80000gn/T/ipykernel_970/4090956298.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Location'].fillna(data['Location'].mode()[0],inplace=True)

# %%
data.isna().sum()
# Out:
# jobpost                 0
# date                    0
# Title                   0
# Company                 0
# AnnouncementCode        0
# Term                    0
# Eligibility             0
# Audience                0
# StartDate               0
# Duration                0
# Location                0
# JobDescription          0
# JobRequirment           0
# RequiredQual            0
# Salary                  0
# ApplicationP           60
# OpeningDate           706
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
data.isna().sum()
# Out:
# jobpost                 0
# date                    0
# Title                   0
# Company                 0
# AnnouncementCode        0
# Term                    0
# Eligibility             0
# Audience                0
# StartDate               0
# Duration                0
# Location                0
# JobDescription          0
# JobRequirment           0
# RequiredQual            0
# Salary                  0
# ApplicationP           60
# OpeningDate           706
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
#Handling null values of 'ApplicationP' columns
data['ApplicationP'].value_counts()
data['ApplicationP'] = data['ApplicationP'].fillna(data['ApplicationP'].mode()[0])

# %%
#Handling null values of 'OpeningDate' columns
data['OpeningDate'].value_counts()
data['OpeningDate'] = data['OpeningDate'].fillna(data['OpeningDate'].mode()[0])

# %%
data.isna().sum()
# Out:
# jobpost                 0
# date                    0
# Title                   0
# Company                 0
# AnnouncementCode        0
# Term                    0
# Eligibility             0
# Audience                0
# StartDate               0
# Duration                0
# Location                0
# JobDescription          0
# JobRequirment           0
# RequiredQual            0
# Salary                  0
# ApplicationP            0
# OpeningDate             0
# Deadline               65
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
#Handling null values of 'Deadline' column
data['Deadline'].value_counts()
data['Deadline'] = data['Deadline'].fillna(data['Deadline'].mode()[0])

# %%
data.isna().sum()
# Out:
# jobpost                 0
# date                    0
# Title                   0
# Company                 0
# AnnouncementCode        0
# Term                    0
# Eligibility             0
# Audience                0
# StartDate               0
# Duration                0
# Location                0
# JobDescription          0
# JobRequirment           0
# RequiredQual            0
# Salary                  0
# ApplicationP            0
# OpeningDate             0
# Deadline                0
# Notes               16790
# AboutC               6531
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
#Handling null values of 'AboutC' column
data['AboutC'].value_counts()
data['AboutC'] = data['AboutC'].fillna(data['AboutC'].mode()[0])

# %%
data.isna().sum()
# Out:
# jobpost                 0
# date                    0
# Title                   0
# Company                 0
# AnnouncementCode        0
# Term                    0
# Eligibility             0
# Audience                0
# StartDate               0
# Duration                0
# Location                0
# JobDescription          0
# JobRequirment           0
# RequiredQual            0
# Salary                  0
# ApplicationP            0
# OpeningDate             0
# Deadline                0
# Notes               16790
# AboutC                  0
# Attach              17442
# Year                    0
# Month                   0
# IT                      0
# dtype: int64

# %%
#Drop irrevelavent columns
data = data.drop(columns = ['Notes','Attach'])

# %%
data.isna().sum()
# Out:
# jobpost             0
# date                0
# Title               0
# Company             0
# AnnouncementCode    0
# Term                0
# Eligibility         0
# Audience            0
# StartDate           0
# Duration            0
# Location            0
# JobDescription      0
# JobRequirment       0
# RequiredQual        0
# Salary              0
# ApplicationP        0
# OpeningDate         0
# Deadline            0
# AboutC              0
# Year                0
# Month               0
# IT                  0
# dtype: int64

# %%
#Cleaning JobDescription and JobRequirement
data['JobDescription'].value_counts()
import re


skills = ['python', 'java', 'sql', 'react', 'node.js', 'c++', 'javascript', 'html', 'css']


# Function to clean the text
def clean_tokenize_lowercase_extract_skills(text):
    # Remove HTML tags
    text = re.sub(r'<.*?>', '', text)
    # Remove special characters (keeping only letters, digits, and spaces)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # Remove excessive whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    # Tokenize by splitting the text on spaces
    tokens = text.split()
    # Convert tokens to lowercase
    tokens = [token.lower() for token in tokens]
    
    # Extract key skills from the text
    extracted_skills = [skill for skill in skills if skill in tokens]
    
    return tokens, extracted_skills

# Apply the function to both columns
data[['Cleaned_Description', 'Extracted_Skills']] = data['JobDescription'].apply(clean_tokenize_lowercase_extract_skills).apply(pd.Series)
data[['Cleaned_Requirement', 'Extracted_Skills_Requirement']] = data['JobRequirment'].apply(clean_tokenize_lowercase_extract_skills).apply(pd.Series)

# %%
data['JobDescription'].value_counts()
# Out:
# JobDescription
# ...

# %%
data.head()
# Out:
#                                              jobpost          date  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI...   Jan 5, 2004
# 1  International Research & Exchanges Board (IREX...   Jan 7, 2004
# 2  Caucasus Environmental NGO Network (CENN)\r\nJ...   Jan 7, 2004
# 3  Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n...   Jan 7, 2004
# 4  Yerevan Brandy Company\r\nJOB TITLE:  Software...  Jan 10, 2004
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode     Term  \
# 0             AMERIA Investment Consulting Company          Unknown  Unknown
# 1  International Research & Exchanges Board (IREX)          Unknown  Unknown
# ...

# %%
#Normalizing Title
data['Title'].replace("Software Developer","Software Eng")
# Out:
# 0                                  Chief Financial Officer
# 1        Full-time Community Connections Intern (paid i...
# 2                                      Country Coordinator
# 3                                           BCC Specialist
# 4                                             Software Eng
#                                ...
# 18996                      Senior Creative UX/ UI Designer
# 18997                         Category Development Manager
# 18998                        Operational Marketing Manager
# 18999                      Head of Online Sales Department
# 19000                           Lawyer in Legal Department
# Name: Title, Length: 19001, dtype: object

# %%
#Date Operations
#Convert date, StartDate, OpeningDate, Deadline into datetime format.
data['date'] = pd.to_datetime(data['date'],errors='coerce')
#data['StartDate'] = pd.to_datetime(data['StartDate'],errors='coerce')

# %%
data.head()
# Out:
#                                              jobpost       date  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI... 2004-01-05
# 1  International Research & Exchanges Board (IREX... 2004-01-07
# 2  Caucasus Environmental NGO Network (CENN)\r\nJ... 2004-01-07
# 3  Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n... 2004-01-07
# 4  Yerevan Brandy Company\r\nJOB TITLE:  Software... 2004-01-10
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode     Term  \
# 0             AMERIA Investment Consulting Company          Unknown  Unknown
# 1  International Research & Exchanges Board (IREX)          Unknown  Unknown
# ...

# %%
data.head()
# Out:
#                                              jobpost       date  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI... 2004-01-05
# 1  International Research & Exchanges Board (IREX... 2004-01-07
# 2  Caucasus Environmental NGO Network (CENN)\r\nJ... 2004-01-07
# 3  Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n... 2004-01-07
# 4  Yerevan Brandy Company\r\nJOB TITLE:  Software... 2004-01-10
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode     Term  \
# 0             AMERIA Investment Consulting Company          Unknown  Unknown
# 1  International Research & Exchanges Board (IREX)          Unknown  Unknown
# ...

# %%
data['StartDate'].unique()
# Out:
# array(['Unknown', 'Immediately', '27 April 2004', ...,
#        'On/ about 06 March 2015 - 07 June 2016', '21 December 2015',
#        '18 January 2016'], shape=(1187,), dtype=object)

# %%
data['Salary'].unique()
# Out:
# array(['Competitive',
#        'Salary is dependent on education, experience, and\r\ncapabilities, and will be discussed on a case-by-case basis.',
#        'Negotiable', ...,
#        '800,000 AMD - 1,000,000 AMD (Gross) plus bonuses.',
#        'Highly competitive plus a social package and\r\nopportunity for training abroad.',
#        'Based on the companys remuneration scheme.'],
#       shape=(2692,), dtype=object)

# %%
data.head()
# Out:
#                                              jobpost       date  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI... 2004-01-05
# 1  International Research & Exchanges Board (IREX... 2004-01-07
# 2  Caucasus Environmental NGO Network (CENN)\r\nJ... 2004-01-07
# 3  Manoff Group\r\nJOB TITLE:  BCC Specialist\r\n... 2004-01-07
# 4  Yerevan Brandy Company\r\nJOB TITLE:  Software... 2004-01-10
#
#                                                Title  \
# 0                            Chief Financial Officer
# 1  Full-time Community Connections Intern (paid i...
# 2                                Country Coordinator
# 3                                     BCC Specialist
# 4                                 Software Developer
#
#                                            Company AnnouncementCode     Term  \
# 0             AMERIA Investment Consulting Company          Unknown  Unknown
# 1  International Research & Exchanges Board (IREX)          Unknown  Unknown
# ...

# %%
'''
 Splitting & Extracting Data
• Split Location into City & Country.
• Extract numeric salary range from Salary (e.g., "50K-60K USD" →
min_salary=50000, max_salary=60000).
'''


import pandas as pd
import re


data = {
    'jobpost': ['AMERIA Investment Consulting Company\r\nJOB TI...', 'International Research & Exchanges Board (IREX)...'],
    'Location': ['New York, USA', 'London, UK'],  # Assuming this column exists
    'Salary': ['50K-60K USD', '40K-50K GBP']  # Assuming this column exists
}

# Create DataFrame
df = pd.DataFrame(data)

# 1. **Splitting `Location` into `City` and `Country`**
df[['City', 'Country']] = df['Location'].str.split(',', expand=True)

# 2. **Extracting numeric salary range from `Salary`**
def extract_salary_range(salary_str):
    # Regex to extract the salary range
    match = re.search(r'(\d+)(K)-(\d+)(K)', salary_str)
    if match:
        min_salary = int(match.group(1)) * 1000  # Convert 'K' to actual number (e.g., 50K -> 50000)
        max_salary = int(match.group(3)) * 1000  # Convert 'K' to actual number (e.g., 60K -> 60000)
        return min_salary, max_salary
    return None, None

# Apply the function to extract min and max salary
df[['min_salary', 'max_salary']] = df['Salary'].apply(lambda x: pd.Series(extract_salary_range(x)))

# Display the updated DataFrame
print(df)
# Out:
#                                              jobpost       Location  \
# 0  AMERIA Investment Consulting Company\r\nJOB TI...  New York, USA
# 1  International Research & Exchanges Board (IREX...     London, UK
#
#         Salary      City Country  min_salary  max_salary
# 0  50K-60K USD  New York     USA       50000       60000
# 1  40K-50K GBP    London      UK       40000       50000

# %%
'''
Filtering & Categorization
• Identify IT-related jobs from the IT column.
• Categorize Eligibility and Audience into structured Education Level /
Experience Ranges.
'''

import pandas as pd

# Sample data (replace this with your actual dataset)
data = {
    'jobpost': ['Software Developer', 'Marketing Manager'],
    'IT': [True, False],
    'Eligibility': ['Bachelor', 'Master'],
    'Audience': ['Fresh Graduate', 'Mid-level']
}

# Create DataFrame
df = pd.DataFrame(data)

# 1. **Identify IT-related jobs from the `IT` column**
# Filter IT-related jobs
it_jobs = df[df['IT'] == True]

# Display IT-related jobs
print("IT-related jobs:")
print(it_jobs)

# 2. **Categorize Eligibility and Audience into Education Level / Experience Ranges**
def categorize_eligibility(eligibility):
    # Define education level categories based on eligibility
    if 'Bachelor' in eligibility:
        return 'Bachelor'
    elif 'Master' in eligibility:
        return 'Master'
    elif 'PhD' in eligibility:
        return 'PhD'
    return 'Unknown'

def categorize_audience(audience):
    # Define experience level categories based on audience
    if 'Fresh Graduate' in audience:
        return '0-2 years'
    elif 'Mid-level' in audience:
        return '2-5 years'
    elif 'Senior' in audience:
        return '5+ years'
    return 'Unknown'

# Apply the categorization functions
df['Education_Level'] = df['Eligibility'].apply(categorize_eligibility)
df['Experience_Range'] = df['Audience'].apply(categorize_audience)

# Display the updated DataFrame
print("\nCategorized Data:")
print(df)
# Out:
# IT-related jobs:
#               jobpost    IT Eligibility        Audience
# 0  Software Developer  True    Bachelor  Fresh Graduate
#
# Categorized Data:
#               jobpost     IT Eligibility        Audience Education_Level  \
# 0  Software Developer   True    Bachelor  Fresh Graduate        Bachelor
# 1   Marketing Manager  False      Master       Mid-level          Master
#
#   Experience_Range
# 0        0-2 years
# 1        2-5 years
